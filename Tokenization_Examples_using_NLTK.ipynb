# %%
 # !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\omsai\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\omsai\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\omsai\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\omsai\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\omsai\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\omsai\appdata\roaming\python\python313\site-packages (from click->nltk) (0.4.6)

# %%
corpus = """ Hello Welcome, To krishna's NLP tutorials.
Please correct me if i am wrong
"""

# %%
print(corpus)
# Out:
#  Hello Welcome, To krishna's NLP tutorials.
# Please correct me if i am wrong

# %%
## Tokenization 
## convert sentence into paragraph 
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\omsai\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
#  Hello Welcome, To krishna's NLP tutorials.
# Please correct me if i am wrong

# %%
### Tokenization
## Paragraph --> words
## sentence --> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'To',
#  'krishna',
#  "'s",
#  'NLP',
#  'tutorials',
#  '.',
#  'Please',
#  'correct',
#  'me',
#  'if',
#  'i',
#  'am',
#  'wrong']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'To', 'krishna', "'s", 'NLP', 'tutorials', '.']
# ['Please', 'correct', 'me', 'if', 'i', 'am', 'wrong']

# %%
### word_punct_tokenize
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'To',
#  'krishna',
#  "'",
#  's',
#  'NLP',
#  'tutorials',
#  '.',
#  'Please',
#  'correct',
#  'me',
#  'if',
#  'i',
#  'am',
#  'wrong']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus) ## look at fullstop it included and treated as sentence
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'To',
#  'krishna',
#  "'s",
#  'NLP',
#  'tutorials.',
#  'Please',
#  'correct',
#  'me',
#  'if',
#  'i',
#  'am',
#  'wrong']
